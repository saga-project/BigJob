# %% [markdown]
# # Generating BigJob Usage Statistics out of Redis entries
# Read `cus` and `pilots` from Redis

# %%
# Redis Service to connect to:
# redis://ILikeBigJob_wITH-REdIS@gw68.quarry.iu.teragrid.org:6379
# redis://localhost

# %run archive.py "redis://ILikeBigJob_wITH-REdIS@gw68.quarry.iu.teragrid.org:6379"

# %% [markdown]
# ## Compute Units Executed per Day

# %%
timestamp_index = [datetime.datetime.utcfromtimestamp(float(i["start_time"])) for i in cus]
cus_df = pd.DataFrame(cus, index=timestamp_index, columns=['Executable', 'NumberOfProcesses', "SPMDVariation"])
cus_df_h = cus_df["Executable"].resample("D", how="count")
cus_df_h.plot()

# %% [markdown]
# ## Compute Unit Types

# %%
cus_df["SPMDVariation"].value_counts().plot(kind="barh")

# %% [markdown]
# ## Pilots Executed per Day

# %%
timestamp_index = [datetime.datetime.utcfromtimestamp(float(i["start_time"])) for i in pilots]
#pilot_df = pd.DataFrame.from_dict(pilots)
pilot_df = pd.DataFrame(pilots, index=timestamp_index, columns=['description'])
pilots
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-2914448d55eb> in <module>()
# ----> 1 timestamp_index = [datetime.datetime.utcfromtimestamp(float(i["start_time"])) for i in pilots]
#       2 #pilot_df = pd.DataFrame.from_dict(pilots)
#       3 pilot_df = pd.DataFrame(pilots, index=timestamp_index, columns=['description'])
#       4 pilots
#
# KeyError: 'start_time'

# %%
import matplotlib.pyplot as plt
pilot_df_h = pilot_df.resample("D", how="count")
pilot_df_h.plot()

# %%
pilots
# Out:
# [{'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Running', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Running', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Running', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Done', 'stopped': 'True'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Running', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Running', 'stopped': 'False'},
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Running', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'},
#  {'state': 'Running', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'state': 'Unknown', 'stopped': 'False'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  {'description': 'None'},
#  redis.exceptions.ResponseError('Operation against a key holding the wrong kind of value'),
#  {'description': 'None'},
#  {'state': 'Running', 'stopped': 'False'}]
